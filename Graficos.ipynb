# %%
# !pip install pandas 
# !pip install matplotlib seaborn
# !pip install pandas openpyxl matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_1 = pd.read_excel("C:/Users/Admin/AppData/Local/Programs/Python/Python312/Scripts/pordia2.xlsx")

df_1.head()
# Out:
#     Año    Mes        Día  Siniestros  Fallecidos  Lesionados Graves  \
# 0  2000  Enero      Lunes         617          29                106
# 1  2000  Enero     Martes         507          16                 96
# 2  2000  Enero  Miércoles         467          18                 91
# 3  2000  Enero     Jueves         472          10                 82
# 4  2000  Enero    Viernes         480          14                102
#
#    Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# 0                      102               518               726
# 1                       78               374               548
# 2                       73               307               471
# 3                       78               321               481
# 4                       97               389               588
#
#    Parque Vehicular  Poblacion  \
# 0           2134940   14788299
# 1           2134940   14788299
# 2           2134940   14788299
# 3           2134940   14788299
# ...

# %%
df_2 = pd.read_excel("C:/Users/Admin/AppData/Local/Programs/Python/Python312/Scripts/porregion2.xlsx")

df_2.head()
# Out:
#     Año       Región  Siniestros  Fallecidos  Lesionados Graves  \
# 0  2000     Tarapacá        1701          41                245
# 1  2000  Antofagasta        1484          62                287
# 2  2000      Atacama         586          35                206
# 3  2000     Coquimbo        1329          52                311
# 4  2000   Valparaíso        4799         166                887
#
#    Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# 0                      256              1490              1991
# 1                      316              1306              1909
# 2                      118               742              1066
# 3                      274              1327              1912
# 4                      479              3843              5209
#
#    Parque Vehicular  Poblacion  \
# 0             78374     411515
# 1             78566     474879
# 2             40251     249405
# 3             69248     584333
# 4            232803    1515485
#
# ...

# %%
df_3 = pd.read_excel("C:/Users/Admin/AppData/Local/Programs/Python/Python312/Scripts/porusuario2.xlsx")

df_3.head()
# Out:
#     Año        Usuario  Siniestros  Fallecidos  Lesionados Graves  \
# 0  2002      Automóvil       24511         266               1654
# 1  2002  Bus / Taxibus        8614          60                599
# 2  2002         Camión        3473          73                304
# 3  2002      Camioneta        8125         130                735
# 4  2002         Furgón        3119          32                218
#
#    Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# 0                     1900             11385             14939
# 1                      770              4660              6029
# 2                      219               881              1404
# 3                      735              3365              4835
# 4                      225              1471              1914
#
#    Total de Vehiculos  Siniestros por 10000 vehiculos  \
# 0             1190614                      205.868569
# 1               31703                     2717.093020
# ...

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)

total_general["Promedio Móvil (3 años)"] = (
    total_general["Lesionados por parque vehicular (por 10000 vehiculos)"]
    .rolling(window=3)
    .mean()
)

plt.figure(figsize=(10, 6))

sns.lineplot(data=total_general, x="Año", y="Lesionados por parque vehicular (por 10000 vehiculos)", marker="o", label="Lesionados")

sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", label="Promedio Móvil (3 años)", linestyle="--")

plt.title("Evolución anual de lesionados por parque vehicular")
plt.xlabel("Año")
plt.ylabel("Lesionados por parque vehicular (por 10000 vehiculos)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(str)

variables = ["Lesionados por cantidad de habitantes (por 100000 habitantes)"]

plt.figure(figsize=(10, 6))

for var in variables:
    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

plt.title("Evolución anual de lesionados por habitante")
plt.xlabel("Año")
plt.ylabel("Cantidad")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)

var = "Lesionados por cantidad de habitantes (por 100000 habitantes)"

total_general["Promedio Móvil (3 años)"] = total_general[var].rolling(window=3).mean()

plt.figure(figsize=(10, 6))

sns.lineplot(data=total_general, x="Año", y=var, marker="o", label="Lesionados por habitante")

sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")

plt.title("Evolución anual de lesionados por habitante")
plt.xlabel("Año")
plt.ylabel("Lesionados por cantidad de habitantes (por 100000 habitantes)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(str)

variables = ["Fallecidos por parque vehicular (por 10000 vehiculos)"]

plt.figure(figsize=(10, 6))

for var in variables:
    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

plt.title("Evolución anual de fallecidos por parque vehicular")
plt.xlabel("Año")
plt.ylabel("Cantidad")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)

var = "Fallecidos por parque vehicular (por 10000 vehiculos)"

total_general["Promedio Móvil (3 años)"] = total_general[var].rolling(window=3).mean()

plt.figure(figsize=(10, 6))

sns.lineplot(data=total_general, x="Año", y=var, marker="o", label="Fallecidos por parque vehicular")

sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")

plt.title("Evolución anual de fallecidos por parque vehicular")
plt.xlabel("Año")
plt.ylabel("Fallecidos por parque vehicular (por 10000 vehiculos)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(str)

variables = ["Fallecidos por cantidad de habitantes (por 100000 habitantes)"]

plt.figure(figsize=(10, 6))

for var in variables:
    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

plt.title("Evolución anual de fallecidos por habitante")
plt.xlabel("Año")
plt.ylabel("Cantidad")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)

variables = ["Fallecidos por cantidad de habitantes (por 100000 habitantes)"]

plt.figure(figsize=(10, 6))

for var in variables:
    total_general["Promedio Móvil (3 años)"] = total_general[var].rolling(window=3).mean()

    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

    sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")

plt.title("Evolución anual de fallecidos por habitante")
plt.xlabel("Año")
plt.ylabel("Fallecidos por cantidad de habitantes (por 100000 habitantes)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(str)

variables = ["Siniestros por parque vehicular (por 10000 vehiculos)"]

plt.figure(figsize=(10, 6))

for var in variables:
    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

plt.title("Evolución anual de siniestros por parque vehicular")
plt.xlabel("Año")
plt.ylabel("Cantidad")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)  # Para el eje X

var = "Siniestros por parque vehicular (por 10000 vehiculos)"

total_general["Promedio Móvil (3 años)"] = total_general[var].rolling(window=3).mean()

plt.figure(figsize=(10, 6))

sns.lineplot(data=total_general, x="Año", y=var, marker="o", label="Siniestros por parque vehicular")

sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")

plt.title("Evolución anual de siniestros por parque vehicular")
plt.xlabel("Año")
plt.ylabel("Siniestros por parque vehicular (por 10000 vehiculos)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(str)

variables = ["Siniestros por cantidad de habitantes (por 100000 habitantes)"]

plt.figure(figsize=(10, 6))

for var in variables:
    sns.lineplot(data=total_general, x="Año", y=var, marker="o", label=var)

plt.title("Evolución anual de siniestros por habitante")
plt.xlabel("Año")
plt.ylabel("Cantidad")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_general = df_1[df_1["Mes"].str.lower().str.contains("total general")].copy()

total_general["Año"] = total_general["Año"].astype(int)
total_general = total_general.sort_values("Año")
total_general["Año"] = total_general["Año"].astype(str)

var = "Siniestros por cantidad de habitantes (por 100000 habitantes)"

total_general["Promedio Móvil (3 años)"] = total_general[var].rolling(window=3).mean()

plt.figure(figsize=(10, 6))

sns.lineplot(data=total_general, x="Año", y=var, marker="o", label="Siniestros por habitante")

sns.lineplot(data=total_general, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")

plt.title("Evolución anual de siniestros por habitante")
plt.xlabel("Año")
plt.ylabel("Siniestros por cantidad de habitantes (por 100000 habitantes)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_mensual = df_1[df_1["Mes"].str.startswith("Total ")].copy()

total_mensual["Mes"] = total_mensual["Mes"].str.replace("Total ", "", regex=False)

cols = [ "Siniestros por parque vehicular (por 10000 vehiculos)"]  
for col in cols:
    total_mensual[col] = pd.to_numeric(total_mensual[col], errors="coerce")

total_mensual = total_mensual[total_mensual["Mes"].str.lower() != "general"]
plt.figure(figsize=(14, 6))
sns.barplot(data=total_mensual, x="Mes", y="Siniestros por parque vehicular (por 10000 vehiculos)", hue="Mes", palette="rocket", legend=False )
plt.title("Promedio total de Siniestros por mes por parque vehicular")
plt.xlabel("Mes")
plt.ylabel("Siniestros por parque vehicular (por 10000 vehiculos)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_mensual = df_1[df_1["Mes"].str.startswith("Total ")].copy()

total_mensual["Mes"] = total_mensual["Mes"].str.replace("Total ", "", regex=False)

cols = [ "Siniestros por cantidad de habitantes (por 100000 habitantes)"]  
for col in cols:
    total_mensual[col] = pd.to_numeric(total_mensual[col], errors="coerce")

total_mensual = total_mensual[total_mensual["Mes"].str.lower() != "general"]
plt.figure(figsize=(14, 6))
sns.barplot(data=total_mensual, x="Mes", y="Siniestros por cantidad de habitantes (por 100000 habitantes)", hue="Mes", palette="rocket", legend=False )
plt.title("Promedio total de Siniestros por mes por habitante")
plt.xlabel("Mes")
plt.ylabel("Siniestros por cantidad de habitantes (por 100000 habitantes)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_2 = df_2[df_2["Región"].str.lower() != "total"]
por_region_suma = df_2.groupby("Región")["Siniestros por parque vehicular (por 10000 vehiculos)"].sum().reset_index()

plt.figure(figsize=(14, 6))
sns.barplot(
    data=por_region_suma.sort_values("Siniestros por parque vehicular (por 10000 vehiculos)", ascending=False),
        x="Región", y="Siniestros por parque vehicular (por 10000 vehiculos)", hue="Región", palette="magma", legend=False
)
plt.title("Total de Siniestros por región por parque vehicular")
plt.xlabel("Región")
plt.ylabel("Siniestros por parque vehicular (por 10000 vehiculos)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_2 = df_2[df_2["Región"].str.lower() != "total"]


fusion_regiones = {
    "Los Ríos": "Los Ríos",
    "Los Lagos": "Los Ríos",
    "Arica y Parinacota": "Tarapacá",
    "Tarapacá": "Tarapacá"
}

df_2["Región Fusionada"] = df_2["Región"].replace(fusion_regiones)

por_region_suma = df_2.groupby("Región Fusionada")["Siniestros por parque vehicular (por 10000 vehiculos)"].sum().reset_index()

plt.figure(figsize=(14, 6))
sns.barplot(
    data=por_region_suma.sort_values("Siniestros por parque vehicular (por 10000 vehiculos)", ascending=False),
    x="Región Fusionada",
    y="Siniestros por parque vehicular (por 10000 vehiculos)",
    hue="Región Fusionada",
    palette="magma",
    legend=False
)
plt.title("Total de Siniestros por región (regiones fusionadas) por parque vehicular")
plt.xlabel("Región")
plt.ylabel("Siniestros por parque vehicular (por 10000 vehículos)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_2 = df_2[df_2["Región"].str.lower() != "total"]
por_region_suma = df_2.groupby("Región")["Siniestros por cantidad de habitantes (por 100000 habitantes)"].sum().reset_index()

plt.figure(figsize=(14, 6))
sns.barplot(
    data=por_region_suma.sort_values("Siniestros por cantidad de habitantes (por 100000 habitantes)", ascending=False),
        x="Región", y="Siniestros por cantidad de habitantes (por 100000 habitantes)", hue="Región", palette="magma", legend=False
)
plt.title("Total de Siniestros por región por habitante")
plt.xlabel("Región")
plt.ylabel("Siniestros por cantidad de habitantes (por 100000 habitantes)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
septiembre_total = df_1[df_1["Mes"].str.lower().str.contains("total septiembre")]

septiembre_por_año = septiembre_total.groupby("Año")["Siniestros por parque vehicular (por 10000 vehiculos)"].sum().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=septiembre_por_año, x="Año", y="Siniestros por parque vehicular (por 10000 vehiculos)", marker="o")
plt.xticks(np.arange(2000,2018,1))
plt.title("Evolución de Siniestros en septiembre por año por parque vehicular")
plt.ylabel("Total Siniestros")
plt.xlabel("Año")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
septiembre_total = df_1[df_1["Mes"].str.lower().str.contains("total septiembre")]

septiembre_por_año = septiembre_total.groupby("Año")["Siniestros por parque vehicular (por 10000 vehiculos)"].sum().reset_index()

septiembre_por_año["Año"] = septiembre_por_año["Año"].astype(int)
septiembre_por_año = septiembre_por_año.sort_values("Año")

septiembre_por_año["Promedio Móvil (3 años)"] = septiembre_por_año["Siniestros por parque vehicular (por 10000 vehiculos)"].rolling(window=3).mean()

plt.figure(figsize=(10, 5))
sns.lineplot(data=septiembre_por_año, x="Año", y="Siniestros por parque vehicular (por 10000 vehiculos)", marker="o", label="Original")
sns.lineplot(data=septiembre_por_año, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")
plt.xticks(np.arange(2000, 2018, 1))
plt.title("Evolución de siniestros en septiembre por parque vehicular")
plt.ylabel("Siniestros (por 10,000 vehículos)")
plt.xlabel("Año")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
septiembre_total = df_1[df_1["Mes"].str.lower().str.contains("total septiembre")]

septiembre_por_año = septiembre_total.groupby("Año")["Siniestros por cantidad de habitantes (por 100000 habitantes)"].sum().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=septiembre_por_año, x="Año", y="Siniestros por cantidad de habitantes (por 100000 habitantes)", marker="o")
plt.xticks(np.arange(2000,2018,1))
plt.title("Evolución de Siniestros en septiembre por año por habitante")
plt.ylabel("Total Siniestros")
plt.xlabel("Año")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
septiembre_total = df_1[df_1["Mes"].str.lower().str.contains("total septiembre")]

septiembre_por_año = septiembre_total.groupby("Año")["Siniestros por cantidad de habitantes (por 100000 habitantes)"].sum().reset_index()

septiembre_por_año["Año"] = septiembre_por_año["Año"].astype(int)
septiembre_por_año = septiembre_por_año.sort_values("Año")

septiembre_por_año["Promedio Móvil (3 años)"] = septiembre_por_año["Siniestros por cantidad de habitantes (por 100000 habitantes)"].rolling(window=3).mean()

plt.figure(figsize=(10, 5))
sns.lineplot(data=septiembre_por_año, x="Año", y="Siniestros por cantidad de habitantes (por 100000 habitantes)", marker="o", label="Original")
sns.lineplot(data=septiembre_por_año, x="Año", y="Promedio Móvil (3 años)", marker="s", linestyle="--", label="Promedio Móvil (3 años)")
plt.xticks(np.arange(2000, 2018, 1))
plt.title("Evolución de siniestros en septiembre por habitante")
plt.ylabel("Siniestros (por 100,000 habitantes)")
plt.xlabel("Año")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_filtrado = df_3[df_3["Usuario"].str.strip().str.lower() != "total general"]

total_por_usuario = df_filtrado.groupby("Usuario")["Siniestros por 10000 vehiculos"].sum().reset_index()

total_por_usuario = total_por_usuario.sort_values(by="Siniestros por 10000 vehiculos", ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(data=total_por_usuario, x="Usuario", y="Siniestros por 10000 vehiculos",
            palette="mako", hue="Usuario", legend=False)
plt.title("Total de Siniestros por tipo de usuario")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_filtrado = df_3[df_3["Usuario"].str.strip().str.lower() != "total general"]

agrupacion = {
    "automóvil": "vehículos menores",
    "camioneta": "vehículos menores",
    "bus": "vehículos mayores",
    "taxibus": "vehículos mayores",
    "camión": "vehículos mayores",
    "furgón": "vehículos mayores",
    "minibus": "vehículos mayores",
    "motocicleta": "motocicleta"
}

df_filtrado["Grupo Usuario"] = df_filtrado["Usuario"].str.strip().str.lower().map(agrupacion)

total_por_grupo = df_filtrado.groupby("Grupo Usuario")["Siniestros por 10000 vehiculos"].sum().reset_index()

total_por_grupo = total_por_grupo.sort_values(by="Siniestros por 10000 vehiculos", ascending=False)

plt.figure(figsize=(8, 6))
sns.barplot(data=total_por_grupo, x="Grupo Usuario", y="Siniestros por 10000 vehiculos", palette="mako")
plt.title("Total de Siniestros por Grupo de Vehículos")
plt.ylabel("Siniestros por 10.000 vehículos")
plt.xlabel("Grupo de vehículos")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7900\2209884471.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=total_por_grupo, x="Grupo Usuario", y="Siniestros por 10000 vehiculos", palette="mako")

# %%
df_filtrado = df_3[df_3["Usuario"].str.strip().str.lower() != "total general"]

agrupacion = {
    "automóvil": "vehículos menores",
    "camioneta": "vehículos menores",
    "bus": "vehículos mayores",
    "taxibus": "vehículos mayores",
    "camión": "vehículos mayores",
    "furgón": "vehículos mayores",
    "minibus": "vehículos mayores",
    "motocicleta": "motocicleta"
}

df_filtrado["Grupo Usuario"] = df_filtrado["Usuario"].str.strip().str.lower().map(agrupacion)

total_por_grupo_anio = df_filtrado.groupby(["Año", "Grupo Usuario"])["Siniestros por 10000 vehiculos"].sum().reset_index()

total_por_grupo_anio = total_por_grupo_anio.sort_values(by="Año")

plt.figure(figsize=(12, 6))
sns.barplot(data=total_por_grupo_anio, x="Año", y="Siniestros por 10000 vehiculos", hue="Grupo Usuario", palette="mako")
plt.title("Siniestros por 10.000 vehículos agrupados por Año y Tipo de Vehículo")
plt.ylabel("Siniestros por 10.000 vehículos")
plt.xlabel("Año")
plt.legend(title="Grupo de Vehículos")
plt.tight_layout()
plt.show()

# %%
por_anio = df_3.groupby("Año")["Total de Vehiculos"].sum().reset_index()

por_anio["Parque vehicular por 10000"] = por_anio["Total de Vehiculos"] / 10000

plt.figure(figsize=(12, 6))
sns.lineplot(data=por_anio, x="Año", y="Parque vehicular por 10000", marker="o")
plt.title("Evolución del Parque Vehicular por cada 10.000 vehículos")
plt.xlabel("Año")
plt.ylabel("Parque vehicular (en unidades de 10.000)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
por_anio = df_3.groupby("Año")["Total de Vehiculos"].sum().reset_index()
por_anio = por_anio.sort_values("Año")
por_anio["Año"] = por_anio["Año"].astype(int)

por_anio["Parque vehicular por 10000"] = por_anio["Total de Vehiculos"] / 10000

plt.figure(figsize=(12, 6))
sns.lineplot(data=por_anio, x="Año", y="Parque vehicular por 10000", label="Valor Anual", marker="o")

plt.xticks(por_anio["Año"])

plt.title("Evolución del Parque Vehicular (por cada 10.000) con Promedio Móvil")
plt.xlabel("Año")
plt.ylabel("Parque vehicular (en unidades de 10.000)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_1.isna().sum()
df_2.isna().sum()
df_3.isna().sum()
# Out:
# Año                               0
# Usuario                           0
# Siniestros                        0
# Fallecidos                        0
# Lesionados Graves                 0
# Lesionados Menos graves           0
# Lesionados Leves                  0
# Total lesionados                  0
# Total de Vehiculos                0
# Siniestros por 10000 vehiculos    0
# Fallecidos por 10000 vehiculos    0
# Lesionados por 10000 vehiculos    0
# dtype: int64

# %%
print(df_1.duplicated().sum())
print(df_2.duplicated().sum())
print(df_3.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
df_1.describe()
# Out:
#                Año    Siniestros   Fallecidos  Lesionados Graves  \
# count  1843.000000   1843.000000  1843.000000        1843.000000
# mean   2009.000000   1899.131850    50.033098         228.612046
# std       5.478712   6516.030822   164.965214         754.886070
# min    2000.000000    318.000000     3.000000          40.000000
# 25%    2004.000000    564.500000    14.500000          75.000000
# 50%    2009.000000    725.000000    20.000000          90.000000
# 75%    2014.000000   1021.000000    28.000000         111.000000
# max    2018.000000  94879.000000  1782.000000        8830.000000
#
#        Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# count              1843.000000       1843.000000       1843.000000
# mean                150.205100       1255.072708       1633.889853
# std                 503.399282       4182.514571       5410.369847
# min                  23.000000        235.000000        345.000000
# ...

# %%
df_2.describe()
# Out:
#                Año    Siniestros  Fallecidos  Lesionados Graves  \
# count   271.000000    271.000000  271.000000         271.000000
# mean   2009.309963   4305.162362  113.420664         518.243542
# std       5.431037   6317.187519  106.412128         619.075786
# min    2000.000000    185.000000    1.000000          31.000000
# 25%    2005.000000   1192.500000   39.500000         150.500000
# 50%    2009.000000   1852.000000   79.000000         333.000000
# 75%    2014.000000   4385.000000  147.000000         544.500000
# max    2018.000000  33303.000000  517.000000        3247.000000
#
#        Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# count               271.000000        271.000000        271.000000
# mean                340.501845       2845.140221       3703.885609
# std                 448.663727       3218.589082       4232.830601
# min                  15.000000        159.000000        257.000000
# ...

# %%
df_3.describe()
# Out:
#               Año    Siniestros  Fallecidos  Lesionados Graves  \
# count   136.00000    136.000000  136.000000         136.000000
# mean   2010.00000  10757.948529  179.492647         811.580882
# std       4.91709  13407.760689  210.273156         744.483421
# min    2002.00000    439.000000    3.000000          49.000000
# 25%    2006.00000   3792.750000   37.000000         223.500000
# 50%    2010.00000   6891.500000   84.500000         476.500000
# 75%    2014.00000   9483.250000  208.250000        1635.250000
# max    2018.00000  67386.000000  817.000000        2445.000000
#
#        Lesionados Menos graves  Lesionados Leves  Total lesionados  \
# count               136.000000        136.000000        136.000000
# mean                512.551471       4709.169118       6033.301471
# std                 485.820662       5409.180464       6414.883090
# min                  32.000000        268.000000        352.000000
# ...
